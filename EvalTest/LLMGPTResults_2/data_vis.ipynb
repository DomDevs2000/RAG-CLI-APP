# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

file_path = './rag_metrics.csv'
df = pd.read_csv(file_path)


print(df.head())


print(df.describe())


print(df.isnull().sum())


sns.set(style='whitegrid')


score_columns = [
    'context_precision', 'context_recall', 'context_entity_recall',
    'answer_relevancy', 'answer_similarity', 'answer_correctness',
    'faithfulness', 'harmfulness', 'maliciousness', 'coherence',
    'correctness', 'conciseness'
]


df['question_number'] = df.index + 1
df['answer_number'] = df.groupby('question_number').cumcount() + 1


fig, axes = plt.subplots(4, 3, figsize=(20, 15))
for i, column in enumerate(score_columns):
    ax = axes[i // 3, i % 3]
    valid_data = df[['question_number', column]].dropna()
    if not valid_data.empty:
        sns.lineplot(data=valid_data, x='question_number', y=column, marker='o', ax=ax)
        ax.set_title(f'{column} over Question Numbers')
fig.tight_layout(pad=3.0)
plt.show()


fig, axes = plt.subplots(4, 3, figsize=(20, 15))
for i, column in enumerate(score_columns):
    ax = axes[i // 3, i % 3]
    valid_data = df[['answer_number', column]].dropna()
    if not valid_data.empty:
        sns.lineplot(data=valid_data, x='answer_number', y=column, marker='o', ax=ax)
        ax.set_title(f'{column} over Answer Numbers')
fig.tight_layout(pad=3.0)
plt.show()
# Out:
#                                             question  \
# 0  What determines the entitlement of shareholder...
# 1  What limitations do the covenants in the Inden...
# 2  How can design and manufacturing defects affec...
# 3  What is the purpose of the Indenture in relati...
# 4  How does the Company's investment in manufactu...
#
#                                               answer  \
# 0  The entitlement of shareholders to receive div...
# 1  The covenants in the Indentures set forth limi...
# 2  Design and manufacturing defects can materiall...
# 3  The purpose of the Indenture in relation to th...
# 4  The Company's investment in manufacturing proc...
#
#                                             contexts  \
# 0  ['\n\nRestated Articles of Incorporation (the ...
# 1  [' Notes matured on the applicable Par Call Da...
# 2  [' suppliers experience severe financial probl...
# 3  [' years shares of Common Stock representing a...
# 4  [' supplier relationships. In addition, some o...
#
#                                         ground_truth  context_precision  \
# 0  The entitlement of shareholders to receive div...                1.0
# 1  The answer to given question is not present in...                0.0
# 2  Design and manufacturing defects can materiall...                1.0
# 3  The purpose of the Indenture in relation to th...                1.0
# 4  The answer to given question is not present in...                0.0
#
#    context_recall  context_entity_recall  answer_relevancy  answer_similarity  \
# 0             1.0               0.750000          1.000000           0.975608
# 1             0.0               0.000000          0.932540           0.707165
# 2             1.0               0.000000          0.982335           0.963494
# 3             1.0               0.307692          1.000000           0.985865
# 4             1.0               0.000000          0.985526           0.686709
#
#    answer_correctness  faithfulness  harmfulness  maliciousness  coherence  \
# 0            0.743902         1.000            0              0          1
# 1            0.176791         0.125            0              0          1
# 2            0.522124         1.000            1              0          1
# 3            0.246466         0.875            0              0          1
# 4            0.171677         0.500            0              0          1
#
#    correctness  conciseness
# 0            1            1
# 1            1            1
# 2            1            1
# 3            1            1
# 4            1            1
#        context_precision  context_recall  context_entity_recall  \
# count           9.000000        9.000000               9.000000
# mean            0.777778        0.888889               0.263355
# std             0.440959        0.333333               0.287637
# min             0.000000        0.000000               0.000000
# 25%             1.000000        1.000000               0.000000
# 50%             1.000000        1.000000               0.250000
# 75%             1.000000        1.000000               0.500000
# max             1.000000        1.000000               0.750000
#
#        answer_relevancy  answer_similarity  answer_correctness  faithfulness  \
# count          9.000000           9.000000            9.000000      9.000000
# mean           0.973962           0.907403            0.513196      0.766667
# std            0.022693           0.119967            0.258324      0.335643
# min            0.932540           0.686709            0.171677      0.125000
# 25%            0.963716           0.943888            0.246466      0.500000
# 50%            0.980186           0.963494            0.535972      1.000000
# 75%            0.985526           0.971184            0.743902      1.000000
# max            1.000000           0.985865            0.827558      1.000000
#
#        harmfulness  maliciousness  coherence  correctness  conciseness
# count     9.000000            9.0        9.0          9.0          9.0
# mean      0.111111            0.0        1.0          1.0          1.0
# std       0.333333            0.0        0.0          0.0          0.0
# min       0.000000            0.0        1.0          1.0          1.0
# 25%       0.000000            0.0        1.0          1.0          1.0
# 50%       0.000000            0.0        1.0          1.0          1.0
# 75%       0.000000            0.0        1.0          1.0          1.0
# max       1.000000            0.0        1.0          1.0          1.0
# question                 0
# answer                   0
# contexts                 0
# ground_truth             0
# context_precision        0
# context_recall           0
# context_entity_recall    0
# answer_relevancy         0
# answer_similarity        0
# answer_correctness       0
# faithfulness             0
# harmfulness              0
# maliciousness            0
# coherence                0
# correctness              0
# conciseness              0
# dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the CSV file
file_path = './rag_metrics.csv'
df = pd.read_csv(file_path)


print(df.head())

print(df.describe())

print(df.isnull().sum())

sns.set(style='whitegrid')


score_columns = [
    'context_precision', 'context_recall', 'context_entity_recall',
    'answer_relevancy', 'answer_similarity', 'answer_correctness',
    'faithfulness', 'harmfulness', 'maliciousness', 'coherence',
    'correctness', 'conciseness'
]

df['question_number'] = df.index + 1
df['answer_number'] = df.groupby('question_number').cumcount() + 1


fig, axes = plt.subplots(4, 3, figsize=(20, 15))
for i, column in enumerate(score_columns):
    ax = axes[i // 3, i % 3]
    valid_data = df[['question_number', column]].dropna()
    if not valid_data.empty:
        sns.lineplot(data=valid_data, x='question_number', y=column, marker='o', ax=ax)
        ax.set_title(f'{column} over Question Numbers')
fig.tight_layout(pad=3.0)
plt.show()


fig, axes = plt.subplots(4, 3, figsize=(20, 15))
for i, column in enumerate(score_columns):
    ax = axes[i // 3, i % 3]
    valid_data = df[['answer_number', column]].dropna()
    if not valid_data.empty:
        sns.lineplot(data=valid_data, x='answer_number', y=column, marker='o', ax=ax)
        ax.set_title(f'{column} over Answer Numbers')
fig.tight_layout(pad=3.0)
plt.show()


stats = df[score_columns].agg(['mean', 'std', 'min', 'max']).T


plt.figure(figsize=(12, 8))
x = range(len(score_columns))
plt.errorbar(x, stats['mean'], yerr=stats['std'], fmt='o', label='Mean ± STD')
plt.scatter(x, stats['min'], color='red', label='Min')
plt.scatter(x, stats['max'], color='green', label='Max')
plt.xticks(x, score_columns, rotation=90)
plt.title('Summary of Score Columns')
plt.legend()
plt.tight_layout(pad=3.0)
plt.show()
# Out:
#                                             question  \
# 0  What determines the entitlement of shareholder...
# 1  What limitations do the covenants in the Inden...
# 2  How can design and manufacturing defects affec...
# 3  What is the purpose of the Indenture in relati...
# 4  How does the Company's investment in manufactu...
#
#                                               answer  \
# 0  The entitlement of shareholders to receive div...
# 1  The covenants in the Indentures set forth limi...
# 2  Design and manufacturing defects can materiall...
# 3  The purpose of the Indenture in relation to th...
# 4  The Company's investment in manufacturing proc...
#
#                                             contexts  \
# 0  ['\n\nRestated Articles of Incorporation (the ...
# 1  [' Notes matured on the applicable Par Call Da...
# 2  [' suppliers experience severe financial probl...
# 3  [' years shares of Common Stock representing a...
# 4  [' supplier relationships. In addition, some o...
#
#                                         ground_truth  context_precision  \
# 0  The entitlement of shareholders to receive div...                1.0
# 1  The answer to given question is not present in...                0.0
# 2  Design and manufacturing defects can materiall...                1.0
# 3  The purpose of the Indenture in relation to th...                1.0
# 4  The answer to given question is not present in...                0.0
#
#    context_recall  context_entity_recall  answer_relevancy  answer_similarity  \
# 0             1.0               0.750000          1.000000           0.975608
# 1             0.0               0.000000          0.932540           0.707165
# 2             1.0               0.000000          0.982335           0.963494
# 3             1.0               0.307692          1.000000           0.985865
# 4             1.0               0.000000          0.985526           0.686709
#
#    answer_correctness  faithfulness  harmfulness  maliciousness  coherence  \
# 0            0.743902         1.000            0              0          1
# 1            0.176791         0.125            0              0          1
# 2            0.522124         1.000            1              0          1
# 3            0.246466         0.875            0              0          1
# 4            0.171677         0.500            0              0          1
#
#    correctness  conciseness
# 0            1            1
# 1            1            1
# 2            1            1
# 3            1            1
# 4            1            1
#        context_precision  context_recall  context_entity_recall  \
# count           9.000000        9.000000               9.000000
# mean            0.777778        0.888889               0.263355
# std             0.440959        0.333333               0.287637
# min             0.000000        0.000000               0.000000
# 25%             1.000000        1.000000               0.000000
# 50%             1.000000        1.000000               0.250000
# 75%             1.000000        1.000000               0.500000
# max             1.000000        1.000000               0.750000
#
#        answer_relevancy  answer_similarity  answer_correctness  faithfulness  \
# count          9.000000           9.000000            9.000000      9.000000
# mean           0.973962           0.907403            0.513196      0.766667
# std            0.022693           0.119967            0.258324      0.335643
# min            0.932540           0.686709            0.171677      0.125000
# 25%            0.963716           0.943888            0.246466      0.500000
# 50%            0.980186           0.963494            0.535972      1.000000
# 75%            0.985526           0.971184            0.743902      1.000000
# max            1.000000           0.985865            0.827558      1.000000
#
#        harmfulness  maliciousness  coherence  correctness  conciseness
# count     9.000000            9.0        9.0          9.0          9.0
# mean      0.111111            0.0        1.0          1.0          1.0
# std       0.333333            0.0        0.0          0.0          0.0
# min       0.000000            0.0        1.0          1.0          1.0
# 25%       0.000000            0.0        1.0          1.0          1.0
# 50%       0.000000            0.0        1.0          1.0          1.0
# 75%       0.000000            0.0        1.0          1.0          1.0
# max       1.000000            0.0        1.0          1.0          1.0
# question                 0
# answer                   0
# contexts                 0
# ground_truth             0
# context_precision        0
# context_recall           0
# context_entity_recall    0
# answer_relevancy         0
# answer_similarity        0
# answer_correctness       0
# faithfulness             0
# harmfulness              0
# maliciousness            0
# coherence                0
# correctness              0
# conciseness              0
# dtype: int64
